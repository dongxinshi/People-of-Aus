# %%
import pandas as pd

# %%
df = pd.read_excel('georef-australia-state-suburb.xlsx')

# %%
df = df.drop(columns = ['Geo Shape','Year','Type','Iso 3166-3 Area Code','Official Code Suburb','Official Code State'])

# %%
df = df.rename(columns = {'Official Name Local Government Area':'LGA Name',
           'Official Code Local Government Area':'LGA Code',
           'Official Name Suburb':'Suburb',
           'Official Name State':'State'
})

# %%
df['Suburb'] = df['Suburb'].apply(lambda x: x.split(' (')[0])
df['LGA Name'] = df['LGA Name'].apply(lambda x: x.split(' (')[0])
df['LGA Code'] = df['LGA Code'].apply(lambda x: x.split(','))

# %%
df
# Out:
#                            Geo Point            State LGA Code  \
# 0      -34.9285588427, 138.600647255  South Australia  [40070]
# 1      -34.9084392199, 138.595339143  South Australia  [40070]
# 2      -34.8715662054, 138.765575516  South Australia  [40120]
# 3       -34.852069708, 138.904027773  South Australia  [40120]
# 4      -34.9183610443, 138.735661857  South Australia  [40120]
# ...                              ...              ...      ...
# 15281  -34.8643873977, 137.514663438  South Australia  [48830]
# 15282   -34.578393913, 137.859606899  South Australia  [48830]
# 15283  -34.6475222161, 137.868518326  South Australia  [48830]
# 15284  -34.8976331904, 137.765722418  South Australia  [48830]
# 15285  -34.5176124616, 137.624107687  South Australia  [48830]
#
#               LGA Name          Suburb
# 0             Adelaide        Adelaide
# 1             Adelaide  North Adelaide
# 2       Adelaide Hills       Castambul
# 3       Adelaide Hills   Kenton Valley
# 4       Adelaide Hills   Norton Summit
# ...                ...             ...
# 15281  Yorke Peninsula       Brentwood
# 15282  Yorke Peninsula      Pine Point
# 15283  Yorke Peninsula      Port Julia
# 15284  Yorke Peninsula       Stansbury
# 15285  Yorke Peninsula          Urania
#
# [15286 rows x 5 columns]
