# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('datacleaning for holiday.csv')

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df
# Out:
#            Date                     Holiday Name  \
# 0     1/01/2022                   New Year's Day
# 1     3/01/2022  New Year's Day (additional day)
# 2    26/01/2022                    Australia Day
# 3    14/03/2022                     Canberra Day
# 4    15/04/2022                      Good Friday
# ..          ...                              ...
# 208  25/04/2023                        Anzac Day
# 209   5/06/2023            Western Australia Day
# 210  25/09/2023                 Queen's Birthday
# 211  25/12/2023                   Christmas Day
# 212  26/12/2023                       Boxing Day
#
#                                            Information  \
# 0    New Year's Day is the first day of the calenda...
# 1    As 1 January 2022 falls on a Saturday in 2022,...
# 2                      Always celebrated on 26 January
# 3    Held on the second Monday of March each year i...
# 4    Easter is celebrated with Good Friday and East...
# ...

# %%
dates = []

for row in df['Date']:
    dates.append(datetime.strftime(datetime.strptime(row,'%d/%m/%Y'),'%Y%m%d'))
    
df['Date'] = dates

# %%
df.insert(0, 'TYPE', 'vevent')

# %%
df.to_csv('cleanCalendar.csv')
